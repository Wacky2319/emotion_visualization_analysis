# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import collections
import pprint

path_hue = "./data/pilot_study/csv/each_parameter/df_each_parameter_hue.csv"
each_parameter_list_hue = pd.read_csv(path_hue, header=0, index_col=0)

valence = each_parameter_list_hue.loc["valence"].values
arousal = each_parameter_list_hue.loc["arousal"].values
hue = each_parameter_list_hue.loc["sliderHue"].values

fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
ax = fig.add_subplot(111, projection="3d")
plt.scatter(valence, arousal, hue)
# fig.savefig("./data/pilot_study/image/hue_polar_hist.png")
